# %% [markdown]
# # Weather Forcast Data Cleaning Using Python

# %% [markdown]
# ## Team Name - WeR Aces
# This is the data cleaning file for the Weather-Forecasting Project. The team members involved are Rishabh Mahajan, Suruchi Jain, Ninya Narayanan and Anamika. This is the python file which will be having the code.

# %%
import pandas as pd

# %%
# Load the data into a pandas DataFrame
file_path = '/kaggle/input/new-project/weather_dataset_stage1.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#              Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0        01-01-22       '37.8'               '35.0'                '12.7'
# 1     2022-01-02'       '43.2'               '32.0'                '14.7'
# 2     2022-01-03'       '25.7'               '60.0'                '12.7'
# 3     2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4     2022-01-05'       '23.5'               '30.0'                '-5.3'
# ...           ...          ...                  ...                   ...
# 3898  2022-07-25'       '62.8'               '60.0'                '48.1'
# 3899  2022-07-26'       '60.6'               '68.0'                '48.9'
# 3900  2022-07-27'       '61.7'               '64.0'                '47.4'
# 3901  2022-07-28'       '60.5'               '61.0'                '45.3'
# 3902  2022-07-28'       '60.5'               '61.0'                '45.3'
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %% [markdown]
# # Subtask 1: Correct years for given data set

# %%
# Replace all occurrences of single quotes with an empty string
df = df.applymap(lambda x: x.replace("'", ""))

# Convert the date column to a datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors='coerce') 
df['Date1'] = pd.to_datetime(df['Date1'], format='%Y-%m-%d', errors='coerce') 

# # Drop any rows with invalid dates
df.dropna(subset=['Date'], inplace=True)
df.dropna(subset=['Date1'], inplace=True)
 
df
# Out:
#            Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 1    2022-01-02         43.2                 32.0                  14.7
# 2    2022-01-03         25.7                 60.0                  12.7
# 3    2022-01-04          9.3                 67.0                   0.1
# 4    2022-01-05         23.5                 30.0                  -5.3
# 5    2022-01-06         24.8                 42.0                   4.6
# ...         ...          ...                  ...                   ...
# 3898 2022-07-25         62.8                 60.0                  48.1
# 3899 2022-07-26         60.6                 68.0                  48.9
# 3900 2022-07-27         61.7                 64.0                  47.4
# 3901 2022-07-28         60.5                 61.0                  45.3
# 3902 2022-07-28         60.5                 61.0                  45.3
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %% [markdown]
# # Subtask 2: Removal of duplicate rows and duplicate Columns

# %%
# Remove duplicate rows
df = df.drop_duplicates()
print(df)
# Out:
#            Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 1    2022-01-02         43.2                 32.0                  14.7
# 2    2022-01-03         25.7                 60.0                  12.7
# 3    2022-01-04          9.3                 67.0                   0.1
# 4    2022-01-05         23.5                 30.0                  -5.3
# 5    2022-01-06         24.8                 42.0                   4.6
# ...         ...          ...                  ...                   ...
# 3897 2022-07-24         64.1                 62.0                  49.8
# 3898 2022-07-25         62.8                 60.0                  48.1
# 3899 2022-07-26         60.6                 68.0                  48.9
# 3900 2022-07-27         61.7                 64.0                  47.4
# 3901 2022-07-28         60.5                 61.0                  45.3
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %%
#removing duplicate columns

# Transpose the DataFrame to convert columns to rows
df = df.T

# Remove duplicate rows (which are now columns)
df = df.drop_duplicates()

# Transpose the DataFrame back to its original shape
df = df.T


df
# Out:
#            Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 1    2022-01-02         43.2                 32.0                  14.7
# 2    2022-01-03         25.7                 60.0                  12.7
# 3    2022-01-04          9.3                 67.0                   0.1
# 4    2022-01-05         23.5                 30.0                  -5.3
# 5    2022-01-06         24.8                 42.0                   4.6
# ...         ...          ...                  ...                   ...
# 3897 2022-07-24         64.1                 62.0                  49.8
# 3898 2022-07-25         62.8                 60.0                  48.1
# 3899 2022-07-26         60.6                 68.0                  48.9
# 3900 2022-07-27         61.7                 64.0                  47.4
# 3901 2022-07-28         60.5                 61.0                  45.3
#
#       Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# ...

# %% [markdown]
# # Subtask 3: Fix a few labels in the given data set

# %%
df.columns =['Date','temperature','avg_humidity','avg_dewpoint','avg_barometer','avg_windspeed','avg_gutspeed','avg_direction','rainfall_month','rainfall_year','maxrain_permin','max_temp','min_temp','max_humidity','min_humidity','max_pressure','min_pressure','max_winspeed','max_gutspeed','maxheat_index','month','diff_pressure']

#Average_humidity (%)	 Average dewpoint (°F	 Average barometer (in	 Average windspeed (mph	 Average gustspeed (mph	 Average direction (°deg	 Rainfall for month (in	Rainfall for year (in	 Maximum rain per minute	 Maximum temperature (°F	 Minimum temperature (°F	 Maximum humidity (%	 Minimum humidity (%	 Maximum pressure	 Minimum pressure	 Maximum windspeed (mph	 Maximum gust speed (mph	 Maximum heat index (°F	Date1	 Month	 diff_pressure
df
# Out:
#            Date temperature avg_humidity avg_dewpoint avg_barometer  \
# 1    2022-01-02        43.2         32.0         14.7          29.5
# 2    2022-01-03        25.7         60.0         12.7          29.7
# 3    2022-01-04         9.3         67.0          0.1          30.4
# 4    2022-01-05        23.5         30.0         -5.3          29.9
# 5    2022-01-06        24.8         42.0          4.6          29.8
# ...         ...         ...          ...          ...           ...
# 3897 2022-07-24        64.1         62.0         49.8          29.6
# 3898 2022-07-25        62.8         60.0         48.1          29.7
# 3899 2022-07-26        60.6         68.0         48.9          29.8
# 3900 2022-07-27        61.7         64.0         47.4          29.9
# 3901 2022-07-28        60.5         61.0         45.3          29.7
#
#      avg_windspeed avg_gutspeed avg_direction rainfall_month rainfall_year  \
# ...

# %% [markdown]
# # Subtask 4: Encoding data into suitable format

# %%
df.to_csv(r'weather_forecasting.csv', index = 'false')
